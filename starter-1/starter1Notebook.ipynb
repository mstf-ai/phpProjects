# %% [markdown]
# # PHP notebook
# ---

# %% [markdown]
# ### PHP with Mora-Soft

# %% [markdown]
# // you can vesit 'w3schools.com' to know more.

# %% [markdown]
# #### 1- php print code.

# %%
<?php
echo "Text";
print("Text");
echo "Current PHP version: " . phpversion();
?>

# %% [markdown]
# #### 2- variables.

# %%
<?php 
    $name = "value"; 
?>

# %% [markdown]
# #### 3- comment types.
# ---
# > 1- (// )
#
# > 2- (# )
#
# > 3- (/* */)

# %% [markdown]
# #### 4- Data types.

# %%
<?php 
$name = "Text";                               //string var
$name = 10;                                   //int var
$name = 15.50 ;                               //float var
$name = true ;                                //boolean var
$neme = array("value0", "value1", "value2");  //array var
var_dump($name);                              // to know whitch types of variables you use
?>

# %% [markdown]
# #### 5- Constants variable.

# %%
<?php 
// you cannot update on the value of constant variables like {define();}. not like normal variable {$name}
// you set the value of the constant variable one time. and no updates whith other line code contains the same constant {define();}
define("varName", "varValue", true); // 'case_insensitive default is'(false)
?>

# %% [markdown]
# #### 6- Operators.

# %%
<?php 
    // + , - , * , / 
    // += , -= , *= , /= . (for making calculations on the value of the same var.)
    // == , !== . (equal or not equal.)
?>

# %% [markdown]
# #### 7- if, else, elseif

# %%
<?php 
// if & else
if($name == "value"){
    echo "Hello.";
    } 
else{
     echo "Goodbay";
    }

// elseif
if($name == "value"){
    echo "do some action";
    }
elseif($name == "other value"){
    echo "do an other action";
    } // ... etc
    
else{
    echo "do final action";
    }
?>

# %% [markdown]
# #### 8- while loop.

# %%
<?php 
// while loop
$i = 2 ;

while($i <= 8){
    echo $i; 
    
    $i++;
}
?>

# %% [markdown]
# #### 9- do while loop.

# %%
<?php 
// do while loop.
$i=3;
do{
    echo $i;
}
while($i <= 7);
?>

# %% [markdown]
# #### 10- for loop.

# %%
<?php 
// for loop.
for($name = 1; $name <= 5; $name++){
    echo $name;
    }
?>

# %% [markdown]
# #### 11- foreach loop.

# %%
<?php 
// foreach loop.
    $i= array("القاهرة", "الجيزة", "الاسكندرية", "المنصورة");

    foreach($i as $x){
        echo "<option>".$x."</option>";
    }
?>

# %% [markdown]
# #### 12- indexed array.

# %%
<?php 
// endexed array.
$i= array("السباحة", "كرة القدم", "القراءة", "الكتابة");

echo $i["0"];

// ******in an other way******** //
$i["0"]= "القاهرة";
$i["1"]= "الجيزة";
$i["2"]= "الاسكندرية";
$i["3"]= "اسوان";

echo $i["2"];
?>

# %% [markdown]
# ### PHP with Abdulrahman Jamal

# %% [markdown]
# #### sub title

# %% [markdown]
# ### PHP with Elzero

# %% [markdown]
# #### sub title
